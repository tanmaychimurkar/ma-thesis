# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import logging
tqdm.pandas()
import os
import matplotlib.pyplot as plt

LOGGER = logging.getLogger(__name__)
logging.basicConfig(
    level=logging.INFO,
    filename=os.path.join('/cluster/home/yakram/tan/sbert-local/esco_data_analysis/analysis', 'esco_analysis_EN.log'),
    filemode="w",
    format="%(levelname)s:[%(filename)s:%(lineno)d] - %(message)s [%(asctime)s]",
)

# %%
os.getcwd()
# Out:
# '/cluster/home/yakram'

# %% [markdown]
# #### Define Result Paths and Load Datasets

# %%
RESULTS_PATH = '/cluster/scratch/yakram/sbert_data/turtle_files/english_data/'
LANGUAGE = 'en'

# %%
query_SkillsHier_Broader = pd.read_csv(RESULTS_PATH + 'query_SkillsHier_Broader.rq', index_col='Unnamed: 0', delimiter='\t')
query_SkillsHier_altLabel = pd.read_csv(RESULTS_PATH + 'query_SkillsHier_altLabel.rq', index_col='Unnamed: 0', delimiter='\t')
query_MemConcept_hiddenLabel = pd.read_csv(RESULTS_PATH + 'query_MemConcept_hiddenLabel.rq', index_col='Unnamed: 0', delimiter='\t')
query_SkillsHier_Schemes = pd.read_csv(RESULTS_PATH + 'query_SkillsHier_Schemes.rq', index_col='Unnamed: 0', delimiter='\t')
query_MemConcept_BroaderTransitive = pd.read_csv(RESULTS_PATH + 'query_MemConcept_BroaderTransitive.rq', index_col='Unnamed: 0', delimiter='\t')
query_MemConcept_description = pd.read_csv(RESULTS_PATH + 'query_MemConcept_description.rq', index_col='Unnamed: 0', delimiter='\t')
query_SkillsHier_description = pd.read_csv(RESULTS_PATH + 'query_SkillsHier_description.rq', index_col='Unnamed: 0', delimiter='\t')  # todo: change the name of thef ifle here
query_MemConcept_TopConceptOf = pd.read_csv(RESULTS_PATH + 'query_MemConcept_TopConceptOf.rq', index_col='Unnamed: 0', delimiter='\t')
query_SkillsHier_Narrower = pd.read_csv(RESULTS_PATH + 'query_SkillsHier_Narrower.rq', index_col='Unnamed: 0', delimiter='\t')
query_MemConcept_Broader = pd.read_csv(RESULTS_PATH + 'query_MemConcept_Broader.rq', index_col='Unnamed: 0', delimiter='\t')
query_MemConcept_isOptionalSkillFor = pd.read_csv(RESULTS_PATH + 'query_MemConcept_isOptionalSkillFor.rq', index_col='Unnamed: 0', delimiter='\t')
query_MemConcept_altLabel = pd.read_csv(RESULTS_PATH + 'query_MemConcept_altLabel.rq', index_col='Unnamed: 0', delimiter='\t')
query_MemConcept_RelatedOptionalSkill = pd.read_csv(RESULTS_PATH + 'query_MemConcept_RelatedOptionalSkill.rq', index_col='Unnamed: 0', delimiter='\t')
query_SkillsHier_prefLabel = pd.read_csv(RESULTS_PATH + 'query_SkillsHier_prefLabel.rq', index_col='Unnamed: 0', delimiter='\t')
query_MemConcept_prefLabel = pd.read_csv(RESULTS_PATH + 'query_MemConcept_prefLabel.rq', index_col='Unnamed: 0', delimiter='\t')
query_SkillsHier_BroaderTransitive = pd.read_csv(RESULTS_PATH + 'query_SkillsHier_BroaderTransitive.rq', index_col='Unnamed: 0', delimiter='\t')
query_MemConcept_isEssentialSkillFor = pd.read_csv(RESULTS_PATH + 'query_MemConcept_isEssentialSkillFor.rq', index_col='Unnamed: 0', delimiter='\t')
query_MemConcept_skillReuseLevel = pd.read_csv(RESULTS_PATH + 'query_MemConcept_skillReuseLevel.rq', index_col='Unnamed: 0', delimiter='\t')
query_MemConcept_Narrower = pd.read_csv(RESULTS_PATH + 'query_MemConcept_Narrower.rq', index_col='Unnamed: 0', delimiter='\t')
query_SkillsHier_hiddenLabel = pd.read_csv(RESULTS_PATH + 'query_SkillsHier_hiddenLabel.rq', index_col='Unnamed: 0', delimiter='\t')
query_MemConcept_Schemes = pd.read_csv(RESULTS_PATH + 'query_MemConcept_Schemes.rq', index_col='Unnamed: 0', delimiter='\t')
query_MemConcept_SkillType = pd.read_csv(RESULTS_PATH + 'query_MemConcept_skillType.rq', index_col='Unnamed: 0', delimiter='\t')
query_SkillsHier_SkillType = pd.read_csv(RESULTS_PATH + 'query_SkillsHier_skillType.rq', index_col='Unnamed: 0', delimiter='\t')

# %% [markdown]
# #### Check the total number of skills and occupations, and check their skill types as defined in the ESCO ontology

# %%
query_SkillsHier_Schemes.columns = query_MemConcept_Schemes.columns

# %%
MemConcept_schemes_grouped = query_MemConcept_Schemes.groupby('?a')['?schemes'].apply(list)
SkillsHier_schemes_grouped = query_SkillsHier_Schemes.groupby('?a')['?schemes'].apply(list)

MemConcept_schemes = query_MemConcept_prefLabel.merge(MemConcept_schemes_grouped, on='?a', how='left')
SkillsHier_schemes = query_SkillsHier_prefLabel.merge(SkillsHier_schemes_grouped, on='?a', how='left')

# %%
def get_concept_scheme(x):
    concept_names = []
    for elem in sorted(x):
        concept_names.append(elem.split('/')[-1])
    return ' '.join(concept_names)

def flag_concept_scheme(x):
    if 'skills' in x:
        return 'skill'
    elif 'occupation' in x:
        return 'occupation'


def get_skilltype_name(x):
    last_uri_word= x.split('/')

    if last_uri_word[-1] == 'knowledge':
        return 'knowledge'
    else:
        return 'skill'

# %%
MemConcept_schemes['concept_schemes'] = MemConcept_schemes['?schemes'].progress_apply(get_concept_scheme)
SkillsHier_schemes['concept_schemes'] = SkillsHier_schemes['?schemes'].progress_apply(get_concept_scheme)

Memconcept_SkillsHier_combined = pd.concat([MemConcept_schemes, SkillsHier_schemes], ignore_index=True)

MemConcept_schemes['concept_flag'] = MemConcept_schemes['concept_schemes'].progress_apply(flag_concept_scheme)
Memconcept_SkillsHier_combined['concept_flag'] = Memconcept_SkillsHier_combined['concept_schemes'].progress_apply(flag_concept_scheme)
query_MemConcept_SkillType['skillTypeName'] = query_MemConcept_SkillType['?skillType'].progress_apply(get_skilltype_name)
# Out:
# 100%|██████████| 16899/16899 [00:00<00:00, 250578.17it/s]
# 100%|██████████| 638/638 [00:00<00:00, 252402.00it/s]
# 100%|██████████| 16899/16899 [00:00<00:00, 731841.11it/s]
# 100%|██████████| 17537/17537 [00:00<00:00, 785496.99it/s]
# 100%|██████████| 13891/13891 [00:00<00:00, 624369.90it/s]

# %%
print(f'For language {LANGUAGE}, the total number of unique skills, combining Member Concepts and Skill Hierarchy, are {Memconcept_SkillsHier_combined["concept_flag"].value_counts()["skill"]},\nThe total number of occupations are {Memconcept_SkillsHier_combined["concept_flag"].value_counts()["occupation"]}')

LOGGER.info(f'For language {LANGUAGE}, the total number of unique skills, combining Member Concepts and Skill Hierarchy, are {Memconcept_SkillsHier_combined["concept_flag"].value_counts()["skill"]},\nThe total number of occupations are {Memconcept_SkillsHier_combined["concept_flag"].value_counts()["occupation"]}')
# Out:
# For language en, the total number of unique skills, combining Member Concepts and Skill Hierarchy, are 14529,
# The total number of occupations are 3008

# %%
print(f'For language {LANGUAGE}, the total number of skills types only in Member Concept are {MemConcept_schemes["concept_flag"].value_counts()["skill"]} (excluding skills from ISCO specifications),\nand there are {query_MemConcept_SkillType["skillTypeName"].value_counts()["skill"]} URIs with skill type as `skill`, and {query_MemConcept_SkillType["skillTypeName"].value_counts()["knowledge"]} URIs with skill type as `knowledge`')


LOGGER.info(f'For language {LANGUAGE}, the total number of skills types only in Member Concept are {MemConcept_schemes["concept_flag"].value_counts()["skill"]} (excluding skills from ISCO specifications),\nand there are {query_MemConcept_SkillType["skillTypeName"].value_counts()["skill"]} URIs with skill type as `skill`, and {query_MemConcept_SkillType["skillTypeName"].value_counts()["knowledge"]} URIs with skill type as `knowledge`')
# Out:
# For language en, the total number of skills types only in Member Concept are 13891 (excluding skills from ISCO specifications),
# and there are 10834 URIs with skill type as `skill`, and 3057 URIs with skill type as `knowledge`

# %% [markdown]
# #### Combined DataFrame (SKills and MemberConcept) with Preferred, Alt, Hidden and Desc with concept flag

# %%
skills_combined_uris = Memconcept_SkillsHier_combined[Memconcept_SkillsHier_combined['concept_flag'] == 'skill']['?a'].values.tolist()
occupation_uris = Memconcept_SkillsHier_combined[Memconcept_SkillsHier_combined['concept_flag'] == 'occupation']['?a'].values.tolist()

# %%
assert len(skills_combined_uris) + len(occupation_uris) == Memconcept_SkillsHier_combined.shape[0]

# %%
Memconcept_SkillsHier_combined_copy = Memconcept_SkillsHier_combined.copy(deep=True)
Memconcept_SkillsHier_combined_copy.drop(columns=['?schemes', 'concept_schemes'], inplace=True)
Memconcept_SkillsHier_combined_copy
# Out:
#                                                       ?a  \
# 0      http://data.europa.eu/esco/skill/29b326ea-a9c8...
# 1      http://data.europa.eu/esco/skill/1a61a520-f4a5...
# 2      http://data.europa.eu/esco/occupation/9d2aae3e...
# 3      http://data.europa.eu/esco/skill/f6c10ed9-763a...
# 4      http://data.europa.eu/esco/occupation/f3da16bd...
# ...                                                  ...
# 17532            http://data.europa.eu/esco/isced-f/0510
# 17533            http://data.europa.eu/esco/isced-f/0511
# 17534            http://data.europa.eu/esco/isced-f/0920
# 17535            http://data.europa.eu/esco/isced-f/0512
# 17536            http://data.europa.eu/esco/isced-f/0921
#
#                                               ?prefLabel concept_flag
# 0                               store raw food materials        skill
# 1                               understand written Irish        skill
# 2                              contact centre supervisor   occupation
# 3                                 work with hot nitrogen        skill
# 4               wholesale merchant in flowers and plants   occupation
# ...                                                  ...          ...
# 17532  biological and related sciences not further de...        skill
# 17533                                            biology        skill
# 17534                        welfare not further defined        skill
# 17535                                       biochemistry        skill
# 17536         care of the elderly and of disabled adults        skill
#
# [17537 rows x 3 columns]

# %%
MemConcept_SkillsHier_prefLabel = pd.concat([query_MemConcept_prefLabel, query_SkillsHier_prefLabel])
MemConcept_SkillsHier_altLabel = pd.concat([query_MemConcept_altLabel, query_SkillsHier_altLabel])
MemConcept_SkillsHier_hiddenLabel = pd.concat([query_MemConcept_hiddenLabel, query_SkillsHier_hiddenLabel])
MemConcept_SkillsHier_description = pd.concat([query_MemConcept_description, query_SkillsHier_description])

# %%
 MemConcept_SkillsHier_prefLabel.columns, MemConcept_SkillsHier_altLabel.columns, MemConcept_SkillsHier_hiddenLabel.columns, MemConcept_SkillsHier_description.columns,
# Out:
# (Index(['?a', '?prefLabel'], dtype='object'),
#  Index(['?a', '?altLabel'], dtype='object'),
#  Index(['?a', '?hiddenLabel'], dtype='object'),
#  Index(['?a', '?desc'], dtype='object'))

# %%
MemConcept_SkillsHier_pref_alt_hidden_desc = Memconcept_SkillsHier_combined_copy.merge(MemConcept_SkillsHier_altLabel, on='?a', how='left').merge(MemConcept_SkillsHier_hiddenLabel, on='?a', how='left').merge(MemConcept_SkillsHier_description, on='?a', how='left')

# %%
MemConcept_SkillsHier_pref_alt_hidden_desc
# Out:
#                                                        ?a  \
# 0       http://data.europa.eu/esco/skill/29b326ea-a9c8...
# 1       http://data.europa.eu/esco/skill/29b326ea-a9c8...
# 2       http://data.europa.eu/esco/skill/29b326ea-a9c8...
# 3       http://data.europa.eu/esco/skill/29b326ea-a9c8...
# 4       http://data.europa.eu/esco/skill/29b326ea-a9c8...
# ...                                                   ...
# 310348            http://data.europa.eu/esco/isced-f/0510
# 310349            http://data.europa.eu/esco/isced-f/0511
# 310350            http://data.europa.eu/esco/isced-f/0920
# 310351            http://data.europa.eu/esco/isced-f/0512
# 310352            http://data.europa.eu/esco/isced-f/0921
#
#                                                ?prefLabel concept_flag  \
# 0                                store raw food materials        skill
# 1                                store raw food materials        skill
# 2                                store raw food materials        skill
# 3                                store raw food materials        skill
# 4                                store raw food materials        skill
# ...                                                   ...          ...
# 310348  biological and related sciences not further de...        skill
# 310349                                            biology        skill
# 310350                        welfare not further defined        skill
# 310351                                       biochemistry        skill
# 310352         care of the elderly and of disabled adults        skill
#
#                           ?altLabel ?hiddenLabel  \
# 0         stored raw food materials          NaN
# 1         stored raw food materials          NaN
# 2          store raw food materials          NaN
# 3          store raw food materials          NaN
# 4       stock raw prime ingredients          NaN
# ...                             ...          ...
# 310348                          NaN          NaN
# 310349                          NaN          NaN
# 310350                          NaN          NaN
# 310351                          NaN          NaN
# 310352                          NaN          NaN
#
#                                                     ?desc
# 0       Keep in reserve raw materials and other food s...
# 1       Keep in reserve raw materials and other food s...
# 2       Keep in reserve raw materials and other food s...
# 3       Keep in reserve raw materials and other food s...
# 4       Keep in reserve raw materials and other food s...
# ...                                                   ...
# 310348                                                NaN
# 310349                                                NaN
# 310350                                                NaN
# 310351                                                NaN
# 310352                                                NaN
#
# [310353 rows x 6 columns]

# %%
query_MemConcept_prefLabel
# Out:
#                                                       ?a  \
# 0      http://data.europa.eu/esco/skill/29b326ea-a9c8...
# 1      http://data.europa.eu/esco/skill/1a61a520-f4a5...
# 2      http://data.europa.eu/esco/occupation/9d2aae3e...
# 3      http://data.europa.eu/esco/skill/f6c10ed9-763a...
# 4      http://data.europa.eu/esco/occupation/f3da16bd...
# ...                                                  ...
# 16894  http://data.europa.eu/esco/skill/25f46432-5ee9...
# 16895  http://data.europa.eu/esco/skill/60571d44-dfd4...
# 16896  http://data.europa.eu/esco/skill/3dd3dfa7-51c0...
# 16897  http://data.europa.eu/esco/occupation/a9c30651...
# 16898  http://data.europa.eu/esco/occupation/95d0a616...
#
#                                               ?prefLabel
# 0                               store raw food materials
# 1                               understand written Irish
# 2                              contact centre supervisor
# 3                                 work with hot nitrogen
# 4               wholesale merchant in flowers and plants
# ...                                                  ...
# 16894                  manage needs for stationery items
# 16895               coordinate humanitarian aid missions
# 16896  monitor parameters' compliance in construction...
# 16897                             instructional designer
# 16898                               family social worker
#
# [16899 rows x 2 columns]

# %%
query_MemConcept_altLabel
# Out:
#                                                        ?a  \
# 0       http://data.europa.eu/esco/skill/29b326ea-a9c8...
# 1       http://data.europa.eu/esco/skill/29b326ea-a9c8...
# 2       http://data.europa.eu/esco/skill/29b326ea-a9c8...
# 3       http://data.europa.eu/esco/skill/29b326ea-a9c8...
# 4       http://data.europa.eu/esco/skill/29b326ea-a9c8...
# ...                                                   ...
# 130269  http://data.europa.eu/esco/occupation/a9c30651...
# 130270  http://data.europa.eu/esco/occupation/a9c30651...
# 130271  http://data.europa.eu/esco/occupation/a9c30651...
# 130272  http://data.europa.eu/esco/occupation/a9c30651...
# 130273  http://data.europa.eu/esco/occupation/95d0a616...
#
#                                        ?altLabel
# 0                      stored raw food materials
# 1                       store raw food materials
# 2                    stock raw prime ingredients
# 3                    store materials of raw food
# 4                       stock raw food materials
# ...                                          ...
# 130269                         training designer
# 130270  instructional course design practitioner
# 130271                 learning process designer
# 130272            instructional systems designer
# 130273                      family social worker
#
# [130274 rows x 2 columns]

# %%
query_MemConcept_Narrower
# Out:
#                                                      ?a  \
# 0     http://data.europa.eu/esco/skill/29b326ea-a9c8...
# 1     http://data.europa.eu/esco/skill/f2f9934c-b462...
# 2     http://data.europa.eu/esco/skill/f2f9934c-b462...
# 3     http://data.europa.eu/esco/skill/f2f9934c-b462...
# 4     http://data.europa.eu/esco/skill/f2f9934c-b462...
# ...                                                 ...
# 7800  http://data.europa.eu/esco/skill/1af2db15-2af9...
# 7801  http://data.europa.eu/esco/skill/1af2db15-2af9...
# 7802  http://data.europa.eu/esco/skill/9ce52938-fe28...
# 7803  http://data.europa.eu/esco/skill/1588302d-dfa9...
# 7804  http://data.europa.eu/esco/skill/fdc388ba-c8f4...
#
#                                            ?narroweruri
# 0     http://data.europa.eu/esco/skill/f15b591a-2522...
# 1     http://data.europa.eu/esco/skill/c8665888-bf94...
# 2     http://data.europa.eu/esco/skill/2a8834b9-33a6...
# 3     http://data.europa.eu/esco/skill/1619f337-77d4...
# 4     http://data.europa.eu/esco/skill/96e78f7e-a14f...
# ...                                                 ...
# 7800  http://data.europa.eu/esco/skill/477173ca-5fc2...
# 7801  http://data.europa.eu/esco/skill/99c4c69a-025c...
# 7802  http://data.europa.eu/esco/skill/a7242a8d-3762...
# 7803  http://data.europa.eu/esco/skill/319cc32a-d995...
# 7804  http://data.europa.eu/esco/skill/440f64e5-e66c...
#
# [7805 rows x 2 columns]

# %%
query_MemConcept_Broader
# Out:
#                                                       ?a  \
# 0      http://data.europa.eu/esco/skill/29b326ea-a9c8...
# 1      http://data.europa.eu/esco/skill/1a61a520-f4a5...
# 2      http://data.europa.eu/esco/occupation/9d2aae3e...
# 3      http://data.europa.eu/esco/skill/f6c10ed9-763a...
# 4      http://data.europa.eu/esco/occupation/f3da16bd...
# ...                                                  ...
# 23135  http://data.europa.eu/esco/skill/60571d44-dfd4...
# 23136  http://data.europa.eu/esco/skill/3dd3dfa7-51c0...
# 23137  http://data.europa.eu/esco/skill/3dd3dfa7-51c0...
# 23138  http://data.europa.eu/esco/occupation/a9c30651...
# 23139  http://data.europa.eu/esco/occupation/95d0a616...
#
#                                              ?broaderuri
# 0                http://data.europa.eu/esco/skill/S6.2.3
# 1      http://data.europa.eu/esco/skill/8f4c0fe6-10c7...
# 2                  http://data.europa.eu/esco/isco/C3341
# 3               http://data.europa.eu/esco/skill/S6.13.1
# 4      http://data.europa.eu/esco/occupation/3ac7fbb4...
# ...                                                  ...
# 23135            http://data.europa.eu/esco/skill/S1.2.1
# 23136            http://data.europa.eu/esco/skill/S2.8.2
# 23137  http://data.europa.eu/esco/skill/1de548e0-9535...
# 23138              http://data.europa.eu/esco/isco/C2359
# 23139  http://data.europa.eu/esco/occupation/4b05bef2...
#
# [23140 rows x 2 columns]

# %%
# todo: complete the analysis after adding the datasets for SkillsHier description, for both english and german data

# %% [markdown]
# #### Getting Narrower and Broader URIs for skills dataset, and it's analysis

# %%
def create_relationships_data(relationship_df_original, relationship_name):

    relationship_df = relationship_df_original.copy(deep=True)

    original_columns = relationship_df.columns
    relationship_df.columns = ['?MemConcept_uri', '?a']

    merged_relationship_df = relationship_df.merge(query_MemConcept_prefLabel, on=['?a'], how='left').merge(query_MemConcept_altLabel, on='?a', how='left').merge(query_MemConcept_hiddenLabel, on='?a', how='left').merge(query_MemConcept_description, on='?a', how='left')

    merged_relationship_df.rename(columns={'?MemConcept_uri': original_columns[0], '?a': original_columns[1]}, inplace=True)
    new_columns =  [x + relationship_name for x in merged_relationship_df.columns[2:]]
    for index, column in enumerate(merged_relationship_df.columns[2:]):
        merged_relationship_df.rename(columns={column: new_columns[index]}, inplace=True)

    return merged_relationship_df

# %%
MemConcept_narrower = create_relationships_data(query_MemConcept_Narrower, 'Narrow')
MemConcept_broader = create_relationships_data(query_MemConcept_Broader, 'Broader')
MemConcept_broaderTransitive = create_relationships_data(query_MemConcept_BroaderTransitive, 'BroaderTrans')
MemConcept_isEssential = create_relationships_data(query_MemConcept_isEssentialSkillFor, 'isEssential')
MemConcept_isOptional = create_relationships_data(query_MemConcept_isOptionalSkillFor, 'isOptional')
MemConcept_relatedOptSkill = create_relationships_data(query_MemConcept_RelatedOptionalSkill, 'relatedOptSkill')

# %%
# MemConcept_TopConcept = create_relationships_data(query_MemConcept_TopConceptOf, 'TopConcept')
query_MemConcept_TopConceptOf['top_concept_names'] = query_MemConcept_TopConceptOf['?topConceptOf'].apply(lambda x: x.split('/')[-1])
query_MemConcept_TopConceptOf
# Out:
#                                                       ?a  \
# 0      http://data.europa.eu/esco/skill/29b326ea-a9c8...
# 1      http://data.europa.eu/esco/occupation/9d2aae3e...
# 2      http://data.europa.eu/esco/skill/f6c10ed9-763a...
# 3      http://data.europa.eu/esco/occupation/eaba592d...
# 4      http://data.europa.eu/esco/skill/5279200c-d6ed...
# ...                                                  ...
# 11166  http://data.europa.eu/esco/skill/5d5f0963-a8b7...
# 11167  http://data.europa.eu/esco/skill/32abc65b-333e...
# 11168  http://data.europa.eu/esco/skill/25f46432-5ee9...
# 11169  http://data.europa.eu/esco/skill/60571d44-dfd4...
# 11170  http://data.europa.eu/esco/occupation/a9c30651...
#
#                                            ?topConceptOf   top_concept_names
# 0      http://data.europa.eu/esco/concept-scheme/memb...       member-skills
# 1      http://data.europa.eu/esco/concept-scheme/memb...  member-occupations
# 2      http://data.europa.eu/esco/concept-scheme/memb...       member-skills
# 3      http://data.europa.eu/esco/concept-scheme/memb...  member-occupations
# 4      http://data.europa.eu/esco/concept-scheme/memb...       member-skills
# ...                                                  ...                 ...
# 11166  http://data.europa.eu/esco/concept-scheme/memb...       member-skills
# 11167  http://data.europa.eu/esco/concept-scheme/memb...       member-skills
# 11168  http://data.europa.eu/esco/concept-scheme/memb...       member-skills
# 11169  http://data.europa.eu/esco/concept-scheme/memb...       member-skills
# 11170  http://data.europa.eu/esco/concept-scheme/memb...  member-occupations
#
# [11171 rows x 3 columns]

# %%
MemConcept_skillReuseLevel = pd.DataFrame(query_MemConcept_skillReuseLevel.groupby('?a')['?skillReuseLevel'].apply(list)).reset_index()
MemConcept_skillReuseLevel['reuse_level'] = MemConcept_skillReuseLevel['?skillReuseLevel'].progress_apply(get_concept_scheme)
MemConcept_skillReuseLevel
# Out:
# 100%|██████████| 13891/13891 [00:00<00:00, 590101.45it/s]
#                                                       ?a  \
# 0      http://data.europa.eu/esco/skill/0005c151-5b5a...
# 1      http://data.europa.eu/esco/skill/00064735-8fad...
# 2      http://data.europa.eu/esco/skill/000709ed-2be5...
# 3      http://data.europa.eu/esco/skill/0007bdc2-dd15...
# 4      http://data.europa.eu/esco/skill/00090cc1-1f27...
# ...                                                  ...
# 13886  http://data.europa.eu/esco/skill/ffef5eb3-a15e...
# 13887  http://data.europa.eu/esco/skill/fff0b074-5a76...
# 13888  http://data.europa.eu/esco/skill/fff0e2cd-d0bd...
# 13889  http://data.europa.eu/esco/skill/fff5bc45-b506...
# 13890  http://data.europa.eu/esco/skill/fff74a70-4f82...
#
#                                         ?skillReuseLevel          reuse_level
# 0      [http://data.europa.eu/esco/skill-reuse-level/...      sector-specific
# 1      [http://data.europa.eu/esco/skill-reuse-level/...  occupation-specific
# 2      [http://data.europa.eu/esco/skill-reuse-level/...      sector-specific
# 3      [http://data.europa.eu/esco/skill-reuse-level/...      sector-specific
# 4      [http://data.europa.eu/esco/skill-reuse-level/...         cross-sector
# ...                                                  ...                  ...
# 13886  [http://data.europa.eu/esco/skill-reuse-level/...      sector-specific
# 13887  [http://data.europa.eu/esco/skill-reuse-level/...      sector-specific
# 13888  [http://data.europa.eu/esco/skill-reuse-level/...      sector-specific
# 13889  [http://data.europa.eu/esco/skill-reuse-level/...         cross-sector
# 13890  [http://data.europa.eu/esco/skill-reuse-level/...         cross-sector
#
# [13891 rows x 3 columns]

# %%
relations_list = [MemConcept_narrower,MemConcept_broader,MemConcept_broaderTransitive,MemConcept_isEssential,MemConcept_isOptional,MemConcept_relatedOptSkill]
relations_name = ["MemConcept_narrower","MemConcept_broader","MemConcept_broaderTransitive","MemConcept_isEssential","MemConcept_isOptional","MemConcept_relatedOptSkill","MemConcept_TopConcept"]

# %%
for relation_df, relation_name in zip(relations_list, relations_name):
    print(f'For the dataframe {relation_name}, the unique MemberConcept URIs available are {relation_df["?a"].nunique()} in total dataframe of length {relation_df.shape[0]}, and the label statistics are as follows:\nPrefLabel count: {relation_df[relation_df.columns[2]].nunique()}, '
          f'altLabel count: {relation_df[relation_df.columns[3]].nunique()}, hiddenLabel count: {relation_df[relation_df.columns[4]].nunique()}, desc count: {relation_df[relation_df.columns[5]].nunique()}\n')
# Out:
# For the dataframe MemConcept_narrower, the unique MemberConcept URIs available are 2580 in total dataframe of length 79126, and the label statistics are as follows:
# PrefLabel count: 6271, altLabel count: 49957, hiddenLabel count: 277, desc count: 6269
#
# For the dataframe MemConcept_broader, the unique MemberConcept URIs available are 16899 in total dataframe of length 396840, and the label statistics are as follows:
# PrefLabel count: 2580, altLabel count: 20205, hiddenLabel count: 753, desc count: 2580
#
# For the dataframe MemConcept_broaderTransitive, the unique MemberConcept URIs available are 16899 in total dataframe of length 539192, and the label statistics are as follows:
# PrefLabel count: 2580, altLabel count: 20205, hiddenLabel count: 753, desc count: 2580
#
# For the dataframe MemConcept_isEssential, the unique MemberConcept URIs available are 10970 in total dataframe of length 744603, and the label statistics are as follows:
# PrefLabel count: 3135, altLabel count: 32242, hiddenLabel count: 93, desc count: 3135
#
# For the dataframe MemConcept_isOptional, the unique MemberConcept URIs available are 9862 in total dataframe of length 737412, and the label statistics are as follows:
# PrefLabel count: 6533, altLabel count: 57020, hiddenLabel count: 167, desc count: 6533
#
# For the dataframe MemConcept_relatedOptSkill, the unique MemberConcept URIs available are 6533 in total dataframe of length 772407, and the label statistics are as follows:
# PrefLabel count: 9862, altLabel count: 69103, hiddenLabel count: 644, desc count: 9861

# %%
# todo: add dataframe logic for skillType logic for all the main URIs

# %% [markdown]
# #### Negative Mining

# %%
Narrower_groupby = query_MemConcept_Narrower.groupby(by='?a')['?narroweruri'].apply(list).reset_index()
Broader_groupby = query_MemConcept_Broader.groupby(by='?a')['?broaderuri'].apply(list).reset_index()

# %%
Narrower_Broader_combined = Narrower_groupby.merge(Broader_groupby, on='?a', how='left')
Narrower_Broader_combined['all_uri_combined'] = Narrower_Broader_combined['?narroweruri'] + Narrower_Broader_combined['?broaderuri']
Narrower_Broader_combined
# Out:
#                                                      ?a  \
# 0     http://data.europa.eu/esco/occupation/009d29de...
# 1     http://data.europa.eu/esco/occupation/00c8d1cf...
# 2     http://data.europa.eu/esco/occupation/00cee175...
# 3     http://data.europa.eu/esco/occupation/02eb0ae6...
# 4     http://data.europa.eu/esco/occupation/03d79393...
# ...                                                 ...
# 2575  http://data.europa.eu/esco/skill/ff9b7465-c37a...
# 2576  http://data.europa.eu/esco/skill/ff9ed77c-f19c...
# 2577  http://data.europa.eu/esco/skill/ffc69c38-ce70...
# 2578  http://data.europa.eu/esco/skill/ffe9b8ef-f32a...
# 2579  http://data.europa.eu/esco/skill/fff5bc45-b506...
#
#                                            ?narroweruri  \
# 0     [http://data.europa.eu/esco/occupation/4e7a364...
# 1     [http://data.europa.eu/esco/occupation/f7145f8...
# 2     [http://data.europa.eu/esco/occupation/3a15ec1...
# 3     [http://data.europa.eu/esco/occupation/c5d36ee...
# 4     [http://data.europa.eu/esco/occupation/3b755cd...
# ...                                                 ...
# 2575  [http://data.europa.eu/esco/skill/9ad3c429-04d...
# 2576  [http://data.europa.eu/esco/skill/b94bc156-74b...
# 2577  [http://data.europa.eu/esco/skill/c10d0ba2-e22...
# 2578  [http://data.europa.eu/esco/skill/bfdfba8e-5ce...
# 2579  [http://data.europa.eu/esco/skill/25a713ba-cbc...
#
#                                             ?broaderuri  \
# 0     [http://data.europa.eu/esco/occupation/3900b68...
# 1               [http://data.europa.eu/esco/isco/C7233]
# 2               [http://data.europa.eu/esco/isco/C8331]
# 3               [http://data.europa.eu/esco/isco/C2153]
# 4               [http://data.europa.eu/esco/isco/C2341]
# ...                                                 ...
# 2575          [http://data.europa.eu/esco/isced-f/0713]
# 2576          [http://data.europa.eu/esco/skill/S6.3.6]
# 2577          [http://data.europa.eu/esco/skill/S8.2.3]
# 2578          [http://data.europa.eu/esco/skill/S1.6.3]
# 2579  [http://data.europa.eu/esco/skill/d7a67428-3af...
#
#                                        all_uri_combined
# 0     [http://data.europa.eu/esco/occupation/4e7a364...
# 1     [http://data.europa.eu/esco/occupation/f7145f8...
# 2     [http://data.europa.eu/esco/occupation/3a15ec1...
# 3     [http://data.europa.eu/esco/occupation/c5d36ee...
# 4     [http://data.europa.eu/esco/occupation/3b755cd...
# ...                                                 ...
# 2575  [http://data.europa.eu/esco/skill/9ad3c429-04d...
# 2576  [http://data.europa.eu/esco/skill/b94bc156-74b...
# 2577  [http://data.europa.eu/esco/skill/c10d0ba2-e22...
# 2578  [http://data.europa.eu/esco/skill/bfdfba8e-5ce...
# 2579  [http://data.europa.eu/esco/skill/25a713ba-cbc...
#
# [2580 rows x 4 columns]

# %%
narroweruri_unique = query_MemConcept_Narrower['?narroweruri'].unique().tolist()
broaderuri_unique = query_MemConcept_Broader['?broaderuri'].unique().tolist()
narrower_broader_uris_combined = list(set(narroweruri_unique + broaderuri_unique))
narrower_broader_mapping = Narrower_Broader_combined[['?a', 'all_uri_combined']].to_dict(orient='records')

# %%
def mine_negatives(x):

    negative_uris = []
    remaining_uris = list(set(narrower_broader_uris_combined) - set(x))

    for record in narrower_broader_mapping:
        main_uri_narrower_broader = record['all_uri_combined']

        if set(main_uri_narrower_broader).issubset(remaining_uris):
            negative_uris.append(record['?a'])

    return negative_uris

# %%
MemConcept_negative_uri = pd.read_csv('/cluster/scratch/yakram/sbert_data/turtle_files/Negative_mined.csv', delimiter='\t')

# %%
MemConcept_negative_uri.head()
# Out:
#    Unnamed: 0                                                 ?a  \
# 0           0  http://data.europa.eu/esco/occupation/009d29de...
# 1           1  http://data.europa.eu/esco/occupation/00c8d1cf...
# 2           2  http://data.europa.eu/esco/occupation/00cee175...
# 3           3  http://data.europa.eu/esco/occupation/02eb0ae6...
# 4           4  http://data.europa.eu/esco/occupation/03d79393...
#
#                                         ?narroweruri  \
# 0  ['http://data.europa.eu/esco/occupation/4e7a36...
# 1  ['http://data.europa.eu/esco/occupation/f7145f...
# 2  ['http://data.europa.eu/esco/occupation/3a15ec...
# 3  ['http://data.europa.eu/esco/occupation/c5d36e...
# 4  ['http://data.europa.eu/esco/occupation/3b755c...
#
#                                          ?broaderuri  \
# 0  ['http://data.europa.eu/esco/occupation/3900b6...
# 1          ['http://data.europa.eu/esco/isco/C7233']
# 2          ['http://data.europa.eu/esco/isco/C8331']
# 3          ['http://data.europa.eu/esco/isco/C2153']
# 4          ['http://data.europa.eu/esco/isco/C2341']
#
#                                     all_uri_combined  \
# 0  ['http://data.europa.eu/esco/occupation/4e7a36...
# 1  ['http://data.europa.eu/esco/occupation/f7145f...
# 2  ['http://data.europa.eu/esco/occupation/3a15ec...
# 3  ['http://data.europa.eu/esco/occupation/c5d36e...
# 4  ['http://data.europa.eu/esco/occupation/3b755c...
#
#                                        negative_uris
# 0  ['http://data.europa.eu/esco/occupation/00c8d1...
# 1  ['http://data.europa.eu/esco/occupation/009d29...
# 2  ['http://data.europa.eu/esco/occupation/009d29...
# 3  ['http://data.europa.eu/esco/occupation/009d29...
# 4  ['http://data.europa.eu/esco/occupation/009d29...

# %%
MemConcept_negative_uri.iloc[0]['negative_uris']
# Out:
# "['http://data.europa.eu/esco/occupation/00c8d1cf-24f2-47d1-9f10-765e1c102811', 'http://data.europa.eu/esco/occupation/00cee175-1376-43fb-9f02-ba3d7a910a58', 'http://data.europa.eu/esco/occupation/02eb0ae6-ecdd-4602-9c8e-60ffe6dbe1e2', 'http://data.europa.eu/esco/occupation/03d79393-7b30-4159-945b-01963eddd302', 'http://data.europa.eu/esco/occupation/044d78cc-f62f-4532-83a5-8e04f2889652', 'http://data.europa.eu/esco/occupation/07bd65d7-c13f-443a-bdf6-88903f3822be', 'http://data.europa.eu/esco/occupation/099c6bb0-22d3-4c5d-8bf5-70910af381ef', 'http://data.europa.eu/esco/occupation/0a94df75-6e31-4277-a326-1b01e56b6cb3', 'http://data.europa.eu/esco/occupation/0b14d5d7-1bbe-4403-b9e6-7b0f37fc44fc', 'http://data.europa.eu/esco/occupation/0b2d3242-22a3-4de5-bd29-efd39cdf2c31', 'http://data.europa.eu/esco/occupation/0bf68df5-e808-4c27-abf2-6f85440f2d7f', 'http://data.europa.eu/esco/occupation/0cd729a6-ed11-4338-ac4b-d4b924390128', 'http://data.europa.eu/esco/occupation/0d93706d-32fd-4de3-aa08-be1003e325da', 'http://data.europa.eu/esco/occupation/0da51178-e386-4534-ae71-15ba789ad756', 'http://data.europa.eu/esco/occupation/0dd7e6cd-2e5a-4fae-9ce0-6a3622d4019f', 'http://data.europa.eu/esco/occupation/0ddbf393-38f1-4c22-b14c-fe775008f321', 'http://data.europa.eu/esco/occupation/0e216d47-fc12-43e9-8953-ad8ba11f4b96', 'http://data.europa.eu/esco/occupation/0f5cc4eb-925d-4b99-be6d-b0964a253a9a', 'http://data.europa.eu/esco/occupation/1009be17-7efd-45f1-a033-566bf179c588', 'http://data.europa.eu/esco/occupation/106f79e4-6264-45f1-9e7a-297435cd684b', 'http://data.europa.eu/esco/occupation/107d21c6-973b-411c-89fd-69da48d29ada', 'http://data.europa.eu/esco/occupation/11695786-9fb7-4895-b161-0480419107e4', 'http://data.europa.eu/esco/occupation/11df8941-508c-4103-ad40-52cdf9430a59', 'http://data.europa.eu/esco/occupation/14031d4a-6e99-442f-b4fe-18262b6432b2', 'http://data.europa.eu/esco/occupation/1488589a-7b83-471d-b094-492f5616f4e0', 'http://data.europa.eu/esco/occupation/14eb2c85-fce5-40b6-bcd0-46ac99994b0d', 'http://data.europa.eu/esco/occupation/1822bfc2-e735-449f-ba00-ca71eb5c062b', 'http://data.europa.eu/esco/occupation/189a337d-f6fb-44e2-9e7a-bc27b7b76e0e', 'http://data.europa.eu/esco/occupation/1a07bd7d-2e1d-4930-a84a-1a442b8f2a44', 'http://data.europa.eu/esco/occupation/1a87e487-6761-4374-b6db-100ac5a9ad5a', 'http://data.europa.eu/esco/occupation/1b38a27d-ef98-4d9f-b1b2-8c109bf47e79', 'http://data.europa.eu/esco/occupation/1b4e795d-6e49-4b7b-bb34-585edfd6eb18', 'http://data.europa.eu/esco/occupation/1c862e14-80f8-4aa8-8f1c-fd2ca95b63ad', 'http://data.europa.eu/esco/occupation/1ee1b792-4d5f-4555-be4e-ce7e4c05d1a9', 'http://data.europa.eu/esco/occupation/1f8314c2-01bd-4af4-babc-04d7034591b8', 'http://data.europa.eu/esco/occupation/1fb92021-9576-4c85-8759-f6918e9f0ad4', 'http://data.europa.eu/esco/occupation/21cba86a-68c5-456c-aec2-cc04840b3c0e', 'http://data.europa.eu/esco/occupation/21de0f3b-a71a-4263-a9ba-90c5f3721b4d', 'http://data.europa.eu/esco/occupation/234be692-befb-41df-bdf0-e1b2f4eaf5e7', 'http://data.europa.eu/esco/occupation/24e9f120-eae8-411a-8daf-c48e8ae2f5f6', 'http://data.europa.eu/esco/occupation/26171f39-e85a-448f-bd28-a73a5a99927f', 'http://data.europa.eu/esco/occupation/2662ed6c-a705-4895-8e9d-0a85c08ad908', 'http://data.europa.eu/esco/occupation/27811419-407f-4868-a388-2f7df7aafd91', 'http://data.europa.eu/esco/occupation/29fa406d-de89-4515-be8d-0fe7bda993f1', 'http://data.europa.eu/esco/occupation/2a6784d7-c457-413d-ba99-e320de11fc98', 'http://data.europa.eu/esco/occupation/2af80b12-a73a-4cc2-8af1-d26a1e60738d', 'http://data.europa.eu/esco/occupation/2e8820ba-5b2d-4572-92a1-942dbd02a6d6', 'http://data.europa.eu/esco/occupation/2f5de1ab-eddf-4715-8193-e994912c22ea', 'http://data.europa.eu/esco/occupation/2f5e38a0-6578-4665-bdbd-e2ab505be140', 'http://data.europa.eu/esco/occupation/30c0943c-caa1-411d-b273-26f475971273', 'http://data.europa.eu/esco/occupation/30f3ea93-882a-4525-841c-1d5b4b64076f', 'http://data.europa. ...

# %% [markdown]
# #### Plots of Analysis

# %%
indexes = ['skill', 'occupation']
unq_skills = Memconcept_SkillsHier_combined["concept_flag"].value_counts()["skill"]
unq_occupations = Memconcept_SkillsHier_combined["concept_flag"].value_counts()["occupation"]
values = [unq_skills, unq_occupations]

fig, ax = plt.subplots(figsize = (10,10))
bars = ax.barh(indexes, values)
plt.title(f'Plot showing Total Skills (MemberConcept + ISCO skills) and Occupations for {LANGUAGE}')
ax.bar_label(bars)
# Out:
# [Text(0, 0, '14529'), Text(0, 0, '3008')]

# %%
indexes = ['skill', 'occupation']
count_skills = query_MemConcept_SkillType["skillTypeName"].value_counts()["skill"]
count_knowledge = query_MemConcept_SkillType["skillTypeName"].value_counts()["knowledge"]
values = [count_skills, count_knowledge]

fig, ax = plt.subplots(figsize = (10,10))
bars = ax.barh(indexes, values)
plt.title(f'Plot showing skill types from all the Member Concept skills (Excluding ISCO skills) for language {LANGUAGE}')
ax.bar_label(bars)
# Out:
# [Text(0, 0, '10834'), Text(0, 0, '3057')]

# %%
indexes = ['MemConcept URIs', 'prefLabel', 'altLabel', 'hiddenLabel', 'desc']
values = []
for column in MemConcept_SkillsHier_pref_alt_hidden_desc.columns:
    if column != 'concept_flag':
        values.append(MemConcept_SkillsHier_pref_alt_hidden_desc[column].nunique())

fig, ax = plt.subplots(figsize = (10,10))
bars = ax.barh(indexes, values)
plt.title(f'Plot showing label and descriptions for all available Member Concepts (Skills+Occupations) for {LANGUAGE}')
ax.bar_label(bars)
# Out:
# [Text(0, 0, '17537'),
#  Text(0, 0, '17405'),
#  Text(0, 0, '128560'),
#  Text(0, 0, '1097'),
#  Text(0, 0, '16896')]

# %%
value_df = [query_MemConcept_Narrower, query_MemConcept_Broader, query_MemConcept_BroaderTransitive, query_MemConcept_isEssentialSkillFor, query_MemConcept_isOptionalSkillFor, query_MemConcept_RelatedOptionalSkill]
fig = plt.figure(figsize = (10,10))
gs = fig.add_gridspec(6, hspace=0)
axs = gs.subplots(sharex=True, sharey=False)
fig.suptitle(f'Plot of Narrower, Broader, BroaderTransitive, Essential, Optional, and RelatedOptional skills for all MemConcept Skills in {LANGUAGE}')

for idx, df in enumerate(value_df):
    values = [df.nunique()[df.columns[0]], df.nunique()[df.columns[1]]]
    indexes = df.columns
    bars = axs[idx].barh(indexes, values)
    axs[idx].bar_label(bars)
